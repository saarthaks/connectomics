# %%
from compare_skeleton import prune_mst, prune_ref_tree, compare, draw_trees_side_by_side
import pickle
with open("data/test_mst.pkl", 'rb') as f:
        mst = pickle.load(f)
    
mst, syn_id_wanted, sk_df, sk_csgraph, rood_id_csgraph = prune_mst(mst)
# Out:
# 864691134964448031
# Is the MST still a valid tree:  True
# Number of Nodes:  19

# %%
ref_tree = prune_ref_tree(syn_id_wanted, sk_df, sk_csgraph, rood_id_csgraph)
# Out:
# Is the reference still a valid tree:  True
# Number of Nodes:  19

# %%
number_nodes, tree_distance, seq_editing = compare(mst, ref_tree)
# Out:
# --------------------------------
# Tree editing distance: 19.0
# Sequence editing distance avg: 0.6041666666666666
